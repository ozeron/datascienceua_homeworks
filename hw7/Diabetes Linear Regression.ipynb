# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import seaborn as sns
import warnings
sns.set_style("whitegrid")
sns.set_context("poster")

# special matplotlib argument for improved plots
from matplotlib import rcParams

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# %%
diabetes.data.shape
# Out:
# (442, 10)

# %%
dia = pd.DataFrame(diabetes.data)
# Note: !Data standartized! 
dia.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#           7         8         9
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
dia.describe()
# Out:
#                 AGE           SEX           BMI            BP            S1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  S2            S3            S4            S5            S6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#                 Y
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
plt.scatter(dia.AGE, dia.Y)
plt.xlabel(u"AGE")
plt.ylabel(u"Y")
plt.title(u"Зависимость между AGE и Y")

# %%
plt.scatter(dia.BMI, dia.Y)
plt.xlabel(u"BMI")
plt.ylabel(u"Y")
plt.title(u"Зависимость между BMI и Y")

# %%
plt.scatter(dia.SEX, dia.Y)
plt.xlabel(u"SEX")
plt.ylabel(u"Y")
plt.title(u"Зависимость между SEX и Y")

# %%
plt.scatter(dia.BP, dia.Y)
plt.xlabel(u"BP")
plt.ylabel(u"Y")
plt.title(u"Зависимость между BP и Y")

# %%
sns.regplot(y="Y", x="BP", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S1", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S2", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S3", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S4", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S5", data=dia, fit_reg = True)

# %%
sns.regplot(y="Y", x="S6", data=dia, fit_reg = True)

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pd.DataFrame(zip(X.columns, lm.coef_), columns = ['features', 'estimatedCoefficients'])
# Out:
#   features  estimatedCoefficients
# 0      AGE             -10.012198
# 1      SEX            -239.819089
# 2      BMI             519.839787
# 3       BP             324.390428
# 4       S1            -792.184162
# 5       S2             476.745838
# 6       S3             101.044570
# 7       S4             177.064176
# 8       S5             751.279321
# 9       S6              67.625386

# %%
plt.scatter(dia.Y, lm.predict(X))
plt.xlabel(u"Y: $Y_i$")
plt.ylabel(u"Предсказанные Y: $\hat{Y}_i$")
plt.title(u"Данные реальные и предсказания модели: $Y_i$ vs $\hat{Y}_i$")

# %%
print "Fit a model X_train, and calculate MSE with Y_train:", np.mean((Y_train - lm.predict(X_train)) ** 2)
print "Fit a model X_train, and calculate MSE with X_test, Y_test:", np.mean((Y_test - lm.predict(X_test)) ** 2)
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 2882.11906122
# Fit a model X_train, and calculate MSE with X_test, Y_test: 2770.7317713

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.hlines(y = 0, xmin=0, xmax = 300)
plt.title(u'График остатков на тренировочных (синий) и тестовых (зеленый) данных')
plt.ylabel(u'Остатки')

# %%
# CrossValidation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

# %%
scores = cross_val_score(lm, X, dia.Y, cv=10)
scores
# Out:
# array([ 0.55614411,  0.23056092,  0.35357777,  0.62190498,  0.26587602,
#         0.61819338,  0.41815916,  0.43515232,  0.43436983,  0.68568514])

# %%
print "Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2)
# Out:
# Accuracy: 0.46 (+/- 0.29)

# %%
predicted = cross_val_predict(lm, X, dia.Y, cv=10)

# %%
metrics.explained_variance_score(dia.Y, predicted)
# Out:
# 0.49425371994380707

# %%
metrics.r2_score(dia.Y, predicted)
# Out:
# 0.49425118061883511

# %%
subcolumns = ['AGE', 'BMI', "BP"]
polyn = dia[subcolumns]
poly = sklearn.preprocessing.PolynomialFeatures(2)
df = pd.DataFrame(poly.fit_transform(polyn))
df.columns = poly.get_feature_names(subcolumns)
df = df.drop('1', axis=1)

# %%
df.describe()
# Out:
#                 AGE           BMI            BP       AGE^2     AGE BMI  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  442.000000  442.000000
# mean  -3.639623e-16 -8.013951e-16  1.289818e-16    0.002262    0.000419
# std    4.761905e-02  4.761905e-02  4.761905e-02    0.002605    0.002266
# min   -1.072256e-01 -9.027530e-02 -1.123996e-01    0.000003   -0.007899
# 25%   -3.729927e-02 -3.422907e-02 -3.665645e-02    0.000265   -0.000677
# 50%    5.383060e-03 -7.283766e-03 -5.670611e-03    0.001450    0.000093
# 75%    3.807591e-02  3.124802e-02  3.564384e-02    0.003178    0.001319
# max    1.107267e-01  1.705552e-01  1.320442e-01    0.012260    0.008520
#
#            AGE BP         BMI^2      BMI BP          BP^2
# count  442.000000  4.420000e+02  442.000000  4.420000e+02
# mean     0.000759  2.262443e-03    0.000895  2.262443e-03
# std      0.002120  3.267015e-03    0.002406  2.736522e-03
# min     -0.006650  6.807836e-08   -0.007558  4.557233e-09
# 25%     -0.000237  2.530092e-04   -0.000247  3.076689e-04
# 50%      0.000422  1.133877e-03    0.000344  1.270483e-03
# 75%      0.001783  3.217685e-03    0.001681  3.284857e-03
# max      0.010891  2.908909e-02    0.012440  1.743568e-02

# %%
dfs = pd.DataFrame(sklearn.preprocessing.scale(df))
dfs.columns = df.columns

# %%
dfs.describe()
# Out:
#                 AGE           BMI            BP         AGE^2       AGE BMI  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.215126e-17  4.822688e-17  5.626470e-17 -3.054369e-16  1.647752e-16
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -2.254290e+00 -1.897929e+00 -2.363066e+00 -8.682885e-01 -3.675209e+00
# 25%   -7.841722e-01 -7.196249e-01 -7.706577e-01 -7.676024e-01 -4.841972e-01
# 50%    1.131724e-01 -1.531324e-01 -1.192178e-01 -3.123119e-01 -1.440927e-01
# 75%    8.005001e-01  6.569519e-01  7.493688e-01  3.516935e-01  3.980064e-01
# max    2.327895e+00  3.585718e+00  2.776071e+00  3.842254e+00  3.579478e+00
#
#              AGE BP         BMI^2        BMI BP          BP^2
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -8.088050e-17 -2.089832e-16 -6.530724e-17 -3.858151e-16
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.498977e+00 -6.932747e-01 -3.516583e+00 -8.276938e-01
# 25%   -4.702835e-01 -6.157643e-01 -4.748500e-01 -7.151374e-01
# 50%   -1.589956e-01 -3.458341e-01 -2.289637e-01 -3.629001e-01
# 75%    4.837549e-01  2.927209e-01  3.273126e-01  3.740411e-01
# max    4.785278e+00  8.220666e+00  4.803581e+00  5.550996e+00

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    dfs, diabetes.target, test_size=0.2, random_state = 4)

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pd.DataFrame(zip(X.columns, lm.coef_), columns = ['features', 'estimatedCoefficients'])
# Out:
#   features  estimatedCoefficients
# 0      AGE               6.138541
# 1      SEX              36.830778
# 2      BMI              18.558508
# 3       BP               3.044350
# 4       S1               2.830443
# 5       S2               7.480487
# 6       S3              -1.179836
# 7       S4               6.543586
# 8       S5               0.432239

# %%
print "Fit a model X_train, and calculate MSE with Y_train:", np.mean((Y_train - lm.predict(X_train)) ** 2)
print "Fit a model X_train, and calculate MSE with X_test, Y_test:", np.mean((Y_test - lm.predict(X_test)) ** 2)
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 3482.59647653
# Fit a model X_train, and calculate MSE with X_test, Y_test: 3408.8000541

# %%
print dia.columns
# Out:
# Index([u'AGE', u'SEX', u'BMI', u'BP', u'S1', u'S2', u'S3', u'S4', u'S5', u'S6',
#        u'Y'],
#       dtype='object')

# %%
subcolumns = ['S1', 'S2', "S2", 'S3', 'S4', 'S5', 'S6']
polyn = dia[subcolumns]
poly = sklearn.preprocessing.PolynomialFeatures(2, include_bias=False)
df = pd.DataFrame(poly.fit_transform(polyn))
df.columns = poly.get_feature_names(subcolumns)
dfs = pd.DataFrame(sklearn.preprocessing.scale(df))
dfs.columns = df.columns

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    dfs, diabetes.target, test_size=0.2, random_state = 4)
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print "Fit a model X_train, and calculate MSE with Y_train:", np.mean((Y_train - lm.predict(X_train)) ** 2)
print "Fit a model X_train, and calculate MSE with X_test, Y_test:", np.mean((Y_test - lm.predict(X_test)) ** 2)
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 3447.97513468
# Fit a model X_train, and calculate MSE with X_test, Y_test: 3733.76046134

# %%
scores = cross_val_score(lm, dfs, diabetes.target, cv=10)
scores
# Out:
# array([ 0.46159479, -0.1023528 ,  0.26375733,  0.52473298,  0.23463771,
#         0.46579316,  0.1946639 ,  0.11338763,  0.19968781,  0.46929906])

# %%
subcolumns = ['AGE', 'BMI', "BP", 'S1', 'S2', "S2", 'S3', 'S4', 'S5', 'S6']

# %%
polyn = dia[subcolumns]
poly = sklearn.preprocessing.PolynomialFeatures(2, include_bias=False)
df = pd.DataFrame(poly.fit_transform(polyn))
df.columns = poly.get_feature_names(subcolumns)
dfs = pd.DataFrame(sklearn.preprocessing.scale(df))
dfs.columns = df.columns

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    dfs, diabetes.target, test_size=0.2, random_state = 4)
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print "Fit a model X_train, and calculate MSE with Y_train:", np.mean((Y_train - lm.predict(X_train)) ** 2)
print "Fit a model X_train, and calculate MSE with X_test, Y_test:", np.mean((Y_test - lm.predict(X_test)) ** 2)
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 2594.7056717
# Fit a model X_train, and calculate MSE with X_test, Y_test: 3470.06366106

# %%
scores = cross_val_score(lm, dfs, diabetes.target, cv=10)
scores
# Out:
# array([ 0.42547775,  0.07256126,  0.16033459,  0.63012139,  0.29449513,
#         0.57913698,  0.25135005,  0.11975009,  0.31585473,  0.57767651])

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.hlines(y = 0, xmin=0, xmax = 300)
plt.title(u'График остатков на тренировочных (синий) и тестовых (зеленый) данных')
plt.ylabel(u'Остатки')

# %%
plt.scatter(diabetes.target, lm.predict(dfs))
plt.xlabel(u"Y: $Y_i$")
plt.ylabel(u"Предсказанные Y: $\hat{Y}_i$")
plt.title(u"Данные реальные и предсказания модели: $Y_i$ vs $\hat{Y}_i$")

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
indices = (0, 1)

X_train = diabetes.data[:-20, indices]
X_test = diabetes.data[-20:, indices]
y_train = diabetes.target[:-20]
y_test = diabetes.target[-20:]

ols = LinearRegression()
ols.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
def plot_figs(fig_num, elev, azim, X_train, clf):
    fig = plt.figure(fig_num, figsize=(4, 3))
    plt.clf()
    ax = Axes3D(fig, elev=elev, azim=azim)

    ax.scatter(X_train[:, 0], X_train[:, 1], y_train, c='k', marker='+')
    ax.plot_surface(np.array([[-.1, -.1], [.15, .15]]),
                    np.array([[-.1, .15], [-.1, .15]]),
                    clf.predict(np.array([[-.1, -.1, .15, .15],
                                          [-.1, .15, -.1, .15]]).T
                                ).reshape((2, 2)),
                    alpha=.5)
    ax.set_xlabel('X_1')
    ax.set_ylabel('X_2')
    ax.set_zlabel('Y')
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])

#Generate the three different figures from different views
elev = 43.5
azim = -110
plot_figs(1, elev, azim, X_train, ols)

elev = -.5
azim = 0
plot_figs(2, elev, azim, X_train, ols)

elev = -.5
azim = 90
plot_figs(3, elev, azim, X_train, ols)

plt.show()
